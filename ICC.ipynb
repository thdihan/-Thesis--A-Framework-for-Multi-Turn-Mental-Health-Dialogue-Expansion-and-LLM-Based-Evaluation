# %%
import json

# %%
with open("/content/combined_data.json", 'r', encoding='utf-8') as f:
    combined_data = json.load(f)

# %%
len(combined_data)
# Out:
# 98

# %%
# !pip install pingouin
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pingouin as pg

rows = []
for row in combined_data:

  for model in ['deepseek', 'qwen', 'gemma3']:
      rows.append({
          'subject': row['start_input'],
          'rater': model,
          'rating': row[model]['overall']
      })


df = pd.DataFrame(rows)
icc_result = pg.intraclass_corr(data=df, targets='subject', raters='rater', ratings='rating')

# %%
icc_result
# Out:
#     Type              Description       ICC         F  df1  df2      pval  \
# 0   ICC1   Single raters absolute -0.094317  0.741435   94  190  0.947815
# 1   ICC2     Single random raters  0.091339  1.685561   94  188  0.001316
# 2   ICC3      Single fixed raters  0.186013  1.685561   94  188  0.001316
# 3  ICC1k  Average raters absolute -0.348736  0.741435   94  190  0.947815
# 4  ICC2k    Average random raters  0.231692  1.685561   94  188  0.001316
# 5  ICC3k     Average fixed raters  0.406726  1.685561   94  188  0.001316
#
#            CI95%
# 0  [-0.19, 0.02]
# 1  [-0.01, 0.21]
# 2   [0.06, 0.32]
# 3   [-0.9, 0.06]
# 4  [-0.03, 0.45]
# 5   [0.17, 0.59]
